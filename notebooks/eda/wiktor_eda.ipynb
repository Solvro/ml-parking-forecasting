# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **Ładowanie danych i ich podgląd:**

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Wczytanie danych

current_dir = Path.cwd()
project_root = current_dir.parent.parent 
data_dir = project_root / 'data'

df_parkings = pd.read_parquet(data_dir / 'parkings.parquet', engine='fastparquet')
df_availabilities = pd.read_parquet(data_dir / 'parking_availabilities.parquet', engine='fastparquet')
df_sksusers = pd.read_parquet(data_dir / 'sks_users.parquet', engine='fastparquet')
df_events = pd.read_parquet(data_dir / 'pwr_events.parquet', engine='fastparquet')

# 2. Szybki check jak to wygląda
print("=== PARKINGS ===")
display(df_parkings.head())
print(f"Liczba parkingów: {len(df_parkings)}")

print("\n=== AVAILABILITIES ===")
display(df_availabilities.head())
print(f"Liczba odczytów parkingowych: {len(df_availabilities)}")

print("\n=== SKS USERS ===")
display(df_sksusers.head())
print(f"Liczba odczytów sksowych: {len(df_sksusers)}")

print("\n=== EVENTS ===")
display(df_events.head())
print(f"Liczba eventów: {len(df_events)}")
# Out:
# === PARKINGS ===
#    id symbol type                name open_hour close_hour  places    geo_lan  \
# 0   7    E01    O        Architektura  06:00:00   22:30:00      75  17.054167
# 1   4    WRO    O  Parking Wrońskiego  06:00:00   22:00:00     207  17.055565
# 2   2    C13    O             Polinka      None       None      54  17.058468
# 3   5    D20    O           D20 - D21  06:00:00   22:30:00      76  17.059677
# 4   6  GEO-L    O  GEO LO1 Geocentrum  06:00:00   22:30:00     301  17.055334
#
#      geo_lat  is_active  is_visible  \
# 0  51.118736       True        True
# 1  51.108963       True        True
# 2  51.107390       True        True
# 3  51.110050       True        True
# 4  51.104164       True        True
#
#                                              address  \
# 0          Bolesława Prusa 53/55, 50-317 Wrocław\r\n
# 1                Hoene-Wrońskiego 10, 50-376 Wrocław
# 2  wybrzeże Stanisława Wyspiańskiego 25, 50-370 W...
# 3               Janiszewskiego 8, 50-372 Wrocław\r\n
# 4                   Na Grobli 15, 50-421 Wrocław\r\n
#
#                         created_at                       updated_at
# 0 2025-02-03 07:51:16.241000+00:00 2025-12-06 19:46:06.731000+00:00
# 1 2025-02-03 07:51:16.185000+00:00 2025-12-06 19:46:06.218000+00:00
# 2 2025-02-03 07:51:16.210000+00:00 2025-12-06 19:46:06.343000+00:00
# 3 2025-02-03 07:51:16.222000+00:00 2025-12-06 19:46:06.478000+00:00
# 4 2025-02-03 07:51:16.232000+00:00 2025-12-06 19:46:06.602000+00:00
# Liczba parkingów: 5
#
# === AVAILABILITIES ===
#    id  parking_id  spaces_left  trend               measured_at  \
# 0   1           4            0      0 2025-02-03 07:51:01+00:00
# 1   2           2            4      0 2025-02-03 07:51:01+00:00
# 2   3           5            0      0 2025-02-03 07:51:01+00:00
# 3   4           6          169     -2 2025-02-03 07:51:01+00:00
# 4   5           7           57     -1 2025-02-03 07:51:01+00:00
#
#                         created_at                       updated_at
# 0 2025-02-03 07:51:16.203000+00:00 2025-02-03 07:51:16.203000+00:00
# 1 2025-02-03 07:51:16.217000+00:00 2025-02-03 07:51:16.217000+00:00
# 2 2025-02-03 07:51:16.228000+00:00 2025-02-03 07:51:16.228000+00:00
# 3 2025-02-03 07:51:16.237000+00:00 2025-02-03 07:51:16.237000+00:00
# 4 2025-02-03 07:51:16.246000+00:00 2025-02-03 07:51:16.246000+00:00
# Liczba odczytów parkingowych: 1826529
#
# === SKS USERS ===
#          external_timestamp  active_users  moving_average_21  \
# 0 2025-02-03 05:25:00+00:00             1                  0
# 1 2025-02-03 05:30:00+00:00             1                  1
# 2 2025-02-03 05:35:00+00:00             2                  1
# 3 2025-02-03 05:40:00+00:00             2                  1
# 4 2025-02-03 05:45:00+00:00             3                  1
#
#                         created_at                       updated_at
# 0 2025-02-03 10:25:00.606927+00:00 2025-02-03 22:59:00.896225+00:00
# 1 2025-02-03 10:25:00.606927+00:00 2025-02-03 22:59:00.896225+00:00
# 2 2025-02-03 10:25:00.606927+00:00 2025-02-03 22:59:00.896225+00:00
# 3 2025-02-03 10:25:00.606927+00:00 2025-02-03 22:59:00.896225+00:00
# 4 2025-02-03 10:25:00.606927+00:00 2025-02-03 22:59:00.896225+00:00
# Liczba odczytów sksowych: 77631
#
# === EVENTS ===
#                                                  uid  \
# 0              64etqju29vmbvvmfnrdrdcbce1@google.com
# 1  6th3id9p68p6abb160s66b9k6gqmabb1c9i38bb3cphjeo...
# 2              3molmc2sfn4jbhi8j55gjnrgfs@google.com
# 3  cdh3ec9pcpj30b9l74p6ab9k6oo3ibb16ss38bb568rj2c...
# 4              5e5mi83jagqmb7iarfb593pmjh@google.com
#
#                                              summary  \
# 0                              Dzień Studenta na W-6
# 1  [Studencka Dawka Kultury] Wyjście na Fantastyc...
# 2   II Wrocławskie Studenckie Sympozjum Chemiczne...
# 3                                                ATP
# 4                Mikołajki W7 - cukierki na kampusie
#
#                       start                       end location
# 0 2023-11-17 00:00:00+00:00 2023-11-18 00:00:00+00:00
# 1 2018-11-16 18:00:00+00:00 2018-11-16 21:00:00+00:00
# 2 2013-04-13 08:00:00+00:00 2013-04-13 16:00:00+00:00
# 3 2019-10-15 00:00:00+00:00 2019-10-17 00:00:00+00:00
# 4 2017-12-06 00:00:00+00:00 2017-12-07 00:00:00+00:00
# Liczba eventów: 1065

# %%
print("\n === DATASET: PARKINGS ===")
df_parkings.info()

print("\n === DATASET: AVAILABILITY ===")
df_availabilities.info()

print("\n=== DATASET: SKS USERS ===")
df_sksusers.info()

print("\n=== DATASET: EVENTS ===")
df_events.info()
# Out:
#  === DATASET: PARKINGS ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          5 non-null      int64
#  1   symbol      5 non-null      object
#  2   type        5 non-null      object
#  3   name        5 non-null      object
#  4   open_hour   4 non-null      object
#  5   close_hour  4 non-null      object
#  6   places      5 non-null      int64
#  7   geo_lan     5 non-null      float64
#  8   geo_lat     5 non-null      float64
#  9   is_active   5 non-null      bool
#  10  is_visible  5 non-null      bool
#  11  address     5 non-null      object
#  12  created_at  5 non-null      datetime64[ns, UTC]
#  13  updated_at  5 non-null      datetime64[ns, UTC]
# dtypes: bool(2), datetime64[ns, UTC](2), float64(2), int64(2), object(6)
# memory usage: 622.0+ bytes
#
#  === DATASET: AVAILABILITY ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826529 entries, 0 to 1826528
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   parking_id   int64
#  2   spaces_left  int64
#  3   trend        int64
#  4   measured_at  datetime64[ns, UTC]
#  5   created_at   datetime64[ns, UTC]
#  6   updated_at   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](3), int64(4)
# memory usage: 97.5 MB
#
# === DATASET: SKS USERS ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77631 entries, 0 to 77630
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   external_timestamp  77631 non-null  datetime64[ns, UTC]
#  1   active_users        77631 non-null  int64
#  2   moving_average_21   77631 non-null  int64
#  3   created_at          77631 non-null  datetime64[ns, UTC]
#  4   updated_at          77631 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](3), int64(2)
# memory usage: 3.0 MB
#
# === DATASET: EVENTS ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   uid       1065 non-null   object
#  1   summary   1065 non-null   object
#  2   start     1065 non-null   datetime64[ns, UTC]
#  3   end       1065 non-null   datetime64[ns, UTC]
#  4   location  1065 non-null   object
# dtypes: datetime64[ns, UTC](2), object(3)
# memory usage: 41.7+ KB

# %%
# Ładniejszy pogląd na braki w tabelkach

print("\n === DATASET: PARKINGS ===")
display(df_parkings.isna().sum())

print("\n === DATASET: AVAILABILITY ===")
display(df_availabilities.isna().sum())

print("\n=== DATASET: SKS USERS ===")
display(df_sksusers.isna().sum())

print("\n=== DATASET: EVENTS ===")
display(df_events.isna().sum())
# Out:
#  === DATASET: PARKINGS ===
# id            0
# symbol        0
# type          0
# name          0
# open_hour     1
# close_hour    1
# places        0
# geo_lan       0
# geo_lat       0
# is_active     0
# is_visible    0
# address       0
# created_at    0
# updated_at    0
# dtype: int64
#  === DATASET: AVAILABILITY ===
# id             0
# parking_id     0
# spaces_left    0
# trend          0
# measured_at    0
# created_at     0
# updated_at     0
# dtype: int64
# === DATASET: SKS USERS ===
# external_timestamp    0
# active_users          0
# moving_average_21     0
# created_at            0
# updated_at            0
# dtype: int64
# === DATASET: EVENTS ===
# uid         0
# summary     0
# start       0
# end         0
# location    0
# dtype: int64

# %% [markdown]
# ## **Ogarnianie datasetu:**

# %%
# Uzupełnię NaN'y dla Polinki, jest to parking całodobowy więc przedział będzie 00:00-23:59

df_parkings['open_hour'] = df_parkings['open_hour'].fillna('00:00:00')
df_parkings['close_hour'] = df_parkings['close_hour'].fillna('23:59:59')

# Zamiana dla wszystkich wartości w tych kolumnach aby były na pewno godzinowe fajne

df_parkings['open_hour'] = pd.to_datetime(df_parkings['open_hour'], format='%H:%M:%S').dt.time
df_parkings['close_hour'] = pd.to_datetime(df_parkings['close_hour'], format='%H:%M:%S').dt.time

# %%
# Skoro formaty danych i NaN'y ogarnięte to teraz przydałoby się znormalizować miare wolnych miejsc, wprowadzę nową kolumne occupancy_rate w %.

# Narazie złącze dwa najprostsze do połączenia datasety: df_prakings i df_availabilities,  w jednego dataframe'a z sensownymi kolumnami (df_full)

df_full = df_availabilities.merge(df_parkings[['id', 'name', 'places']], left_on='parking_id', right_on='id', suffixes=('', '_parking'))
df_full['occupancy_rate'] = (df_full['places'] - df_full['spaces_left']) / df_full['places'] * 100
df_full.drop(columns=['created_at', 'updated_at'], inplace = True)


df_full.head()
# Out:
#    id  parking_id  spaces_left  trend               measured_at  id_parking  \
# 0   1           4            0      0 2025-02-03 07:51:01+00:00           4
# 1   2           2            4      0 2025-02-03 07:51:01+00:00           2
# 2   3           5            0      0 2025-02-03 07:51:01+00:00           5
# 3   4           6          169     -2 2025-02-03 07:51:01+00:00           6
# 4   5           7           57     -1 2025-02-03 07:51:01+00:00           7
#
#                  name  places  occupancy_rate
# 0  Parking Wrońskiego     207      100.000000
# 1             Polinka      54       92.592593
# 2           D20 - D21      76      100.000000
# 3  GEO LO1 Geocentrum     301       43.853821
# 4        Architektura      75       24.000000

# %%
# Sprawdzam jeszcze czy teraz w złączonej tabelce nie ma anomalii i czy nie pojawia się ujemne occupancy rate:

# Wtedy kiedy procentowe zajecie miejsc jest ujemne oznacza to ze parking jest pusty, odwrotnie - parking pełny.
anomalies_low = df_full[df_full['occupancy_rate'] < 0]
anomalies_high = df_full[df_full['occupancy_rate'] > 100]

print("=== ANOMALIE ===")
print(f"Wartości ujemne: {len(anomalies_low)} wierszy")
print(f"Wartości powyżej 100%: {len(anomalies_high)} wierszy")

# Sprawdzam który parking jest najbardziej zepsuty
print("\nTopka wadliwych parkingów:")
all_anomalies = pd.concat([anomalies_low, anomalies_high])
print(all_anomalies['name'].value_counts())

print("\nPrzykładowe błędne wiersze:")
display(all_anomalies[['measured_at', 'name', 'places', 'spaces_left', 'occupancy_rate']].head())
# Out:
# === ANOMALIE ===
# Wartości ujemne: 397844 wierszy
# Wartości powyżej 100%: 1210 wierszy
#
# Topka wadliwych parkingów:
# name
# Architektura          272362
# Polinka               125993
# D20 - D21                480
# Parking Wrońskiego       219
# Name: count, dtype: int64
#
# Przykładowe błędne wiersze:
#                    measured_at          name  places  spaces_left  \
# 1839 2025-02-03 16:25:02+00:00  Architektura      75           76
# 1844 2025-02-03 16:27:02+00:00  Architektura      75           76
# 1849 2025-02-03 16:28:01+00:00  Architektura      75           76
# 1854 2025-02-03 16:29:02+00:00  Architektura      75           76
# 1859 2025-02-03 16:30:01+00:00  Architektura      75           76
#
#       occupancy_rate
# 1839       -1.333333
# 1844       -1.333333
# 1849       -1.333333
# 1854       -1.333333
# 1859       -1.333333

# %%
# Clippuje, wszystko poniżej 0 zamień na 0, wszystko powyżej 100 na 100
df_full['occupancy_rate'] = df_full['occupancy_rate'].clip(lower=0, upper=100)

# Skoro zmieniliśmy % zajętości, musimy zaktualizować liczbę wolnych miejsc,
df_full['spaces_left'] = df_full['places'] - (df_full['occupancy_rate'] / 100 * df_full['places'])

# Zaokrąglamy do pełnych aut
df_full['spaces_left'] = df_full['spaces_left'].round().astype(int)

# Sprawdzonko jak to teraz wygląda
print(f"Min occupancy: {df_full['occupancy_rate'].min()}%")
print(f"Max occupancy: {df_full['occupancy_rate'].max()}%")
# Out:
# Min occupancy: 0.0%
# Max occupancy: 100.0%

# %%
# Przed doklejaniem kolejnych feature'ów sortuje dataset
df_full = df_full.sort_values('measured_at')
display(df_full.head())
# Out:
#    id  parking_id  spaces_left  trend               measured_at  id_parking  \
# 0   1           4            0      0 2025-02-03 07:51:01+00:00           4
# 1   2           2            4      0 2025-02-03 07:51:01+00:00           2
# 2   3           5            0      0 2025-02-03 07:51:01+00:00           5
# 3   4           6          169     -2 2025-02-03 07:51:01+00:00           6
# 4   5           7           57     -1 2025-02-03 07:51:01+00:00           7
#
#                  name  places  occupancy_rate
# 0  Parking Wrońskiego     207      100.000000
# 1             Polinka      54       92.592593
# 2           D20 - D21      76      100.000000
# 3  GEO LO1 Geocentrum     301       43.853821
# 4        Architektura      75       24.000000

# %% [markdown]
# ## **Łączenie datasetów:**

# %% [markdown]
# ### **Użytkownicy w sks'ie:**

# %%
# Sortujemy obie tabele po czasie (wymóg aby użyć metody merge_asof)
df_full = df_full.sort_values('measured_at')
df_sksusers = df_sksusers.sort_values('external_timestamp')

# Wybieramm tylko (moim zdaniem) przydatne cechy z sks_userów
sks_subset = df_sksusers[['external_timestamp', 'active_users', 'moving_average_21']]

# %%
# Obliczam odstępy w df_sksusers (SKS)
df_sks_sorted = df_sksusers.sort_values('external_timestamp')
gaps_sks = df_sks_sorted['external_timestamp'].diff().dt.total_seconds() / 60
median_gap_sks = gaps_sks.median()
print(f"SKS - Mediana odstępów: {median_gap_sks:.2f} min")

# Tolerancje przyjmuję jako megidian_gap_sks * 2
suggested_tolerance = median_gap_sks * 2 if median_gap_sks > 0 else 30
print(f"Sugerowana tolerancja: {suggested_tolerance:.2f} min")

# Dla direction: używamy 'backward', aby uniknąć przecieku danych - prognozujemy na podstawie przeszłości, nie przyszłości.

# Używam merge_asof, bo dla każdego pomiaru parkingu znajduje liczbę użytkowników z najbliższego momentu w czasie

df_full = pd.merge_asof(
    df_full,                    # Tabela LEWA (główna)
    sks_subset,                 # Tabela PRAWA (dostawiana)
    left_on='measured_at',      # Czas w parkingu
    right_on='external_timestamp', # Czas w SKS
    direction='backward',        # Szukaj najbliższej wartości W PRZESZŁOŚCI - aby uniknąć przecieku danych
    tolerance=pd.Timedelta(f'{int(suggested_tolerance)} min')  # Maksymalnie sugerowana tolerancja na podstawie analizy odstępów
)

df_full.drop(columns=['external_timestamp'], inplace=True)

display(df_full.head())
# Out:
# SKS - Mediana odstępów: 5.00 min
# Sugerowana tolerancja: 10.00 min
#    id  parking_id  spaces_left  trend               measured_at  id_parking  \
# 0   1           4            0      0 2025-02-03 07:51:01+00:00           4
# 1   2           2            4      0 2025-02-03 07:51:01+00:00           2
# 2   3           5            0      0 2025-02-03 07:51:01+00:00           5
# 3   4           6          169     -2 2025-02-03 07:51:01+00:00           6
# 4   5           7           57     -1 2025-02-03 07:51:01+00:00           7
#
#                  name  places  occupancy_rate  active_users  moving_average_21
# 0  Parking Wrońskiego     207      100.000000          12.0               10.0
# 1             Polinka      54       92.592593          12.0               10.0
# 2           D20 - D21      76      100.000000          12.0               10.0
# 3  GEO LO1 Geocentrum     301       43.853821          12.0               10.0
# 4        Architektura      75       24.000000          12.0               10.0

# %%
# Wizualizacja active_users i moving_average_21 od czasu

plt.figure(figsize=(14, 7))

# Wykres dla active_users
plt.subplot(2, 1, 1)
plt.plot(df_full['measured_at'], df_full['active_users'], color='blue', linewidth=1)
plt.title('Liczba aktywnych użytkowników SKS w czasie')
plt.xlabel('Czas')
plt.ylabel('Aktywni użytkownicy')
plt.grid(True)

# Wykres dla moving_average_21
plt.subplot(2, 1, 2)
plt.plot(df_full['measured_at'], df_full['moving_average_21'], color='green', linewidth=1)
plt.title('21-dniowa średnia ruchoma aktywnych użytkowników SKS')
plt.xlabel('Czas')
plt.ylabel('Średnia ruchoma (21 dni)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Wizualizacja brakujących danych SKS

plt.figure(figsize=(10, 5))
plt.plot(df_full['measured_at'], df_full['active_users'].isna(), marker='o', linestyle='', markersize=2)
plt.title('Brakujące dane SKS w czasie')
plt.xlabel('Czas')
plt.ylabel('Brak danych SKS (True/False)')
plt.show()

# %%
missing_sks = df_full['active_users'].isna().sum()
print(f"Brakujących danych SKS: {missing_sks}")
# Out:
# Brakujących danych SKS: 208785

# %%
# Trzeba uzupełnić i active_users jak i moving_average_21
# Używam interpolacji, method='time' uwzględnia odległości czasowe

df_full['active_users'] = df_full.set_index('measured_at')['active_users'].interpolate(method='time').values
df_full['moving_average_21'] = df_full.set_index('measured_at')['moving_average_21'].interpolate(method='time').values

# Jeśli braki są na samym początku lub końcu pliku, interpolacja tam nie sięgnie. Używam ffill (wypełnij ostatnią znaną) i bfill (wypełnij następną znaną)
df_full['active_users'] = df_full['active_users'].ffill().bfill()
df_full['moving_average_21'] = df_full['moving_average_21'].ffill().bfill()

# Szybki check
print(f"Pozostałe braki SKS: {df_full['active_users'].isna().sum()}, braki w wygładzeniu: {df_full['moving_average_21'].isna().sum()}")
# Out:
# Pozostałe braki SKS: 0, braki w wygładzeniu: 0

# %% [markdown]
# ### **Eventy:**

# %%
# Najpierw sprawdzam jak sie mają eventowe daty do dat parkingowych

print("Zakres Parkingi:", df_full['measured_at'].min(), "do", df_full['measured_at'].max())
print("Zakres Eventy:  ", df_events['start'].min(), "do", df_events['end'].max())  # wtf 😭
# Out:
# Zakres Parkingi: 2025-02-03 07:51:01+00:00 do 2025-12-07 14:53:01+00:00
# Zakres Eventy:   2012-10-16 17:00:00+00:00 do 2040-06-14 00:00:00+00:00

# %%
# Trzeba teraz 'wyciąć' eventy matchujące datą do parkingowych danych

parking_start = df_full['measured_at'].min()
parking_end = df_full['measured_at'].max()

matching_events = df_events[(df_events['end'] >= parking_start) & (df_events['start'] <= parking_end)].copy()

print(f"Liczba eventów matchujących: {len(matching_events)}")

# Przygotowanie do włożenia eventów w df_full

df_full['is_event'] = 0

for idx, row in matching_events.iterrows():
    mask = (df_full['measured_at'] >= row['start']) & (df_full['measured_at'] <= row['end'])
    df_full.loc[mask, 'is_event'] = 1
# Out:
# Liczba eventów matchujących: 121

# %%
# Sprawdzam pokrycie eventowe 2025 roku
event_coverage = df_full['is_event'].mean() * 100
print(f"\nProcent czasu z aktywnym eventem: {event_coverage:.2f}%")
# Out:
# Procent czasu z aktywnym eventem: 29.38%

# %%
# Dodanie feature'u 'important_event' - eventy, które zwiększyły średnią occupancy o minimum 10%

# Obliczenie średniej zajętości dla każdego parkingu
global_mean_occupancy = df_full['occupancy_rate'].mean()
print(f"Globalna średnia zajętość: {global_mean_occupancy:.2f}%")

# Inicjalizacja nowej kolumny
df_full['is_important_event'] = 0

# Dla każdego eventu sprawdzamy czy jest ważny
for idx, row in matching_events.iterrows():
    mask = (df_full['measured_at'] >= row['start']) & (df_full['measured_at'] <= row['end'])
    mean_during_event = df_full[mask]['occupancy_rate'].mean()
    
    if mean_during_event >= global_mean_occupancy * 1.1:
        df_full.loc[mask, 'is_important_event'] = 1
        print(f"Event '{row['summary']}' ({row['start']} - {row['end']}) jest ważny: średnia {mean_during_event:.2f}% (wzrost o {((mean_during_event / global_mean_occupancy - 1) * 100):.2f}%)")

# Sprawdzamy ile mamy important events
important_count = df_full['is_important_event'].sum()
total_event_rows = df_full['is_event'].sum()

df_full.drop(columns=['is_event'], inplace=True)

print(f"\nProcent important eventów wśród wszystkich eventów: {important_count / total_event_rows * 100:.2f}%" if total_event_rows > 0 else "Brak eventów")
important_event_coverage = df_full['is_important_event'].mean() * 100
print(f"Procent czasu z aktywnym WAŻNYM eventem: {important_event_coverage:.2f}%")
# Out:
# Globalna średnia zajętość: 33.44%
# Event 'Geosiata' (2025-05-28 00:00:00+00:00 - 2025-05-29 00:00:00+00:00) jest ważny: średnia 44.20% (wzrost o 32.15%)
# Event 'Rejs W2xW3' (2025-06-05 00:00:00+00:00 - 2025-06-06 00:00:00+00:00) jest ważny: średnia 47.26% (wzrost o 41.30%)
# Event 'Dziki Bajer' (2025-06-06 00:00:00+00:00 - 2025-06-07 00:00:00+00:00) jest ważny: średnia 40.02% (wzrost o 19.65%)
# Event 'Gra samorządowca' (2025-04-24 00:00:00+00:00 - 2025-04-25 00:00:00+00:00) jest ważny: średnia 44.74% (wzrost o 33.78%)
# Event 'Rejs W10 ' (2025-05-27 00:00:00+00:00 - 2025-05-28 00:00:00+00:00) jest ważny: średnia 46.06% (wzrost o 37.72%)
# Event 'Urodziny Wydział Mechaniczny 10.10' (2025-10-10 00:00:00+00:00 - 2025-10-11 00:00:00+00:00) jest ważny: średnia 51.81% (wzrost o 54.93%)
# Event 'WuZet Fest - festyn W8' (2025-06-05 00:00:00+00:00 - 2025-06-06 00:00:00+00:00) jest ważny: średnia 47.26% (wzrost o 41.30%)
# Event 'Rajd jesienny W3xW9xW13' (2025-10-24 00:00:00+00:00 - 2025-10-27 00:00:00+00:00) jest ważny: średnia 37.05% (wzrost o 10.78%)
# Event 'Antmicro Tuesday (W4)' (2025-05-13 00:00:00+00:00 - 2025-05-14 00:00:00+00:00) jest ważny: średnia 46.12% (wzrost o 37.90%)
# Event 'Grill W10' (2025-06-05 00:00:00+00:00 - 2025-06-06 00:00:00+00:00) jest ważny: średnia 47.26% (wzrost o 41.30%)
# Event 'Wydziałówka W4xW7' (2025-05-29 00:00:00+00:00 - 2025-05-30 00:00:00+00:00) jest ważny: średnia 48.20% (wzrost o 44.11%)
# Event 'ŚNIADANIE Z REKTOREM 2025' (2025-05-20 00:00:00+00:00 - 2025-05-21 00:00:00+00:00) jest ważny: średnia 47.55% (wzrost o 42.19%)
# Event 'Warsztateki' (2025-12-03 00:00:00+00:00 - 2025-12-04 00:00:00+00:00) jest ważny: średnia 52.73% (wzrost o 57.67%)
# Event 'Droga do inżyniera - W3' (2025-11-26 00:00:00+00:00 - 2025-11-27 00:00:00+00:00) jest ważny: średnia 52.90% (wzrost o 58.18%)
# Event 'Wydziałówka W4xW6xW11xW12' (2025-11-27 00:00:00+00:00 - 2025-11-28 00:00:00+00:00) jest ważny: średnia 54.85% (wzrost o 64.00%)
# Event 'Otrzęsiny W14' (2025-12-05 00:00:00+00:00 - 2025-12-06 00:00:00+00:00) jest ważny: średnia 49.56% (wzrost o 48.17%)
# Event 'W11 Ubieranie Choinki 🎄' (2025-12-04 08:00:00+00:00 - 2025-12-04 16:00:00+00:00) jest ważny: średnia 85.19% (wzrost o 154.71%)
# Event 'Among PWr' (2025-11-25 17:00:00+00:00 - 2025-11-25 23:00:00+00:00) jest ważny: średnia 43.48% (wzrost o 30.01%)
#
# Procent important eventów wśród wszystkich eventów: 60.20%
# Procent czasu z aktywnym WAŻNYM eventem: 17.69%

# %% [markdown]
# ### **Dodawanie dodatkowych cech i robienie porządku w finalnym datasecie:**

# %%
# Podsumowując, po dodaniu całości otrzymaliśmy:

df_full.head(10)
# Out:
#    id  parking_id  spaces_left  trend               measured_at  id_parking  \
# 0   1           4            0      0 2025-02-03 07:51:01+00:00           4
# 1   2           2            4      0 2025-02-03 07:51:01+00:00           2
# 2   3           5            0      0 2025-02-03 07:51:01+00:00           5
# 3   4           6          169     -2 2025-02-03 07:51:01+00:00           6
# 4   5           7           57     -1 2025-02-03 07:51:01+00:00           7
# 5   6           4            0      0 2025-02-03 07:54:01+00:00           4
# 6   7           2            4      0 2025-02-03 07:54:01+00:00           2
# 7   8           5            0      0 2025-02-03 07:54:01+00:00           5
# 8   9           6          164     -3 2025-02-03 07:54:01+00:00           6
# 9  10           7           57      0 2025-02-03 07:54:01+00:00           7
#
#                  name  places  occupancy_rate  active_users  \
# 0  Parking Wrońskiego     207      100.000000          12.0
# 1             Polinka      54       92.592593          12.0
# 2           D20 - D21      76      100.000000          12.0
# 3  GEO LO1 Geocentrum     301       43.853821          12.0
# 4        Architektura      75       24.000000          12.0
# 5  Parking Wrońskiego     207      100.000000          12.0
# 6             Polinka      54       92.592593          12.0
# 7           D20 - D21      76      100.000000          12.0
# 8  GEO LO1 Geocentrum     301       45.514950          12.0
# 9        Architektura      75       24.000000          12.0
#
#    moving_average_21  is_important_event
# 0               10.0                   0
# 1               10.0                   0
# 2               10.0                   0
# 3               10.0                   0
# 4               10.0                   0
# 5               10.0                   0
# 6               10.0                   0
# 7               10.0                   0
# 8               10.0                   0
# 9               10.0                   0

# %%
# Będę pracował teraz na df_model

df_model = df_full.copy()
df_model = df_model.sort_values(by=['name', 'measured_at'])

# Usunięcie zbędnych kolumn
cols_to_drop = ['id', 'parking_id', 'id_parking', 'spaces_left']
df_model = df_model.drop(columns=[c for c in df_model.columns if c in cols_to_drop])

# Wyciągnięcie czasowych cech
df_model['hour'] = df_model['measured_at'].dt.hour
df_model['day_of_week'] = df_model['measured_at'].dt.dayofweek
df_model['month'] = df_model['measured_at'].dt.month
df_model['is_weekend'] = (df_model['day_of_week'] >= 5).astype(int)

holiday_dates = [
    '2025-01-01',  # Nowy Rok
    '2025-01-06',  # Trzech Króli
    '2025-03-31',  # Wielkanoc
    '2025-04-01',  # Poniedziałek Wielkanocny
    '2025-05-01',  # Święto Pracy
    '2025-05-03',  # Święto Konstytucji 3 Maja
    '2025-05-19',  # Zielone Świątki
    '2025-05-30',  # Boże Ciało
    '2025-08-15',  # Wniebowzięcie NMP
    '2025-11-01',  # Wszystkich Świętych
    '2025-11-11',  # Święto Niepodległości
    '2025-12-25',  # Boże Narodzenie
    '2025-12-26'   # Drugi dzień Bożego Narodzenia
]
df_model['is_holiday'] = df_model['measured_at'].dt.date.astype(str).isin(holiday_dates).astype(int)

# Dodanie lagów

df_model['lag_1h'] = df_model.groupby('name')['occupancy_rate'].shift(60)
df_model['lag_3h'] = df_model.groupby('name')['occupancy_rate'].shift(180)
df_model['lag_24h'] = df_model.groupby('name')['occupancy_rate'].shift(1440)
df_model['lag_72h'] = df_model.groupby('name')['occupancy_rate'].shift(4320)
df_model['lag_7d'] = df_model.groupby('name')['occupancy_rate'].shift(10080)
df_model = df_model.dropna()

# Manualny one-hot encoding dla nazw parkingów
unique_parking_names = df_model['name'].unique()
for parking in unique_parking_names:
    df_model[parking] = (df_model['name'] == parking).astype(int)
df_model.drop(columns=['name'], inplace=True)

# Szybki check jak to się prezentuje
print("=== GOTOWE DANE DO MODELU ===")
print(df_model.info())
display(df_model.head())
# Out:
# === GOTOWE DANE DO MODELU ===
# <class 'pandas.core.frame.DataFrame'>
# Index: 1776129 entries, 50404 to 1826527
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   trend               int64
#  1   measured_at         datetime64[ns, UTC]
#  2   places              int64
#  3   occupancy_rate      float64
#  4   active_users        float64
#  5   moving_average_21   float64
#  6   is_important_event  int64
#  7   hour                int32
#  8   day_of_week         int32
#  9   month               int32
#  10  is_weekend          int64
#  11  is_holiday          int64
#  12  lag_1h              float64
#  13  lag_3h              float64
#  14  lag_24h             float64
#  15  lag_72h             float64
#  16  lag_7d              float64
#  17  Architektura        int64
#  18  D20 - D21           int64
#  19  GEO LO1 Geocentrum  int64
#  20  Parking Wrońskiego  int64
#  21  Polinka             int64
# dtypes: datetime64[ns, UTC](1), float64(8), int32(3), int64(10)
# memory usage: 291.3 MB
# None
#        trend               measured_at  places  occupancy_rate  active_users  \
# 50404      0 2025-02-12 23:57:01+00:00      75             0.0           0.0
# 50409      0 2025-02-12 23:58:02+00:00      75             0.0           0.0
# 50411      0 2025-02-12 23:59:01+00:00      75             0.0           0.0
# 50419      0 2025-02-13 00:00:02+00:00      75             0.0           1.0
# 50424      0 2025-02-13 00:02:02+00:00      75             0.0           1.0
#
#        moving_average_21  is_important_event  hour  day_of_week  month  ...  \
# 50404                3.0                   0    23            2      2  ...
# 50409                3.0                   0    23            2      2  ...
# 50411                3.0                   0    23            2      2  ...
# 50419                4.0                   0     0            3      2  ...
# 50424                4.0                   0     0            3      2  ...
#
#        lag_1h  lag_3h  lag_24h  lag_72h  lag_7d  Architektura  D20 - D21  \
# 50404     0.0     0.0      0.0      0.0    24.0             1          0
# 50409     0.0     0.0      0.0      0.0    24.0             1          0
# 50411     0.0     0.0      0.0      0.0    24.0             1          0
# 50419     0.0     0.0      0.0      0.0    24.0             1          0
# 50424     0.0     0.0      0.0      0.0    24.0             1          0
#
#        GEO LO1 Geocentrum  Parking Wrońskiego  Polinka
# 50404                   0                   0        0
# 50409                   0                   0        0
# 50411                   0                   0        0
# 50419                   0                   0        0
# 50424                   0                   0        0
#
# [5 rows x 22 columns]

# %%
# Kolumny z nazwami parkingów
parking_cols = [col for col in df_model.columns if col not in ['trend', 'measured_at', 'places', 'occupancy_rate','is_holiday', 'active_users', 'moving_average_21', 'is_important_event', 'hour', 'day_of_week', 'month', 'is_weekend', 'lag_1h', 'lag_3h', 'lag_24h', 'lag_72h', 'lag_7d']]

# Dla każdego parkingu tworzę osobny df
for col in parking_cols:
    
    parking_name = col
    df_name = f'df_model_{parking_name.replace(' ', '_').lower()}'
    
    # Filtruje wiersze gdzie ten parking ma 1
    globals()[df_name] = df_model[df_model[col] == 1].copy()
    
    # Usuwam wszsytkie kolumny z nazwami parkingów
    globals()[df_name] = globals()[df_name].drop(columns=parking_cols)
    # Ustawiam index jako mierzony czas
    globals()[df_name] = globals()[df_name].set_index('measured_at')
    
    print(f"Stworzono {df_name} z {len(globals()[df_name])} wierszami")
    display(globals()[df_name].head())
# Out:
# Stworzono df_model_architektura z 355226 wierszami
#                            trend  places  occupancy_rate  active_users  \
# measured_at
# 2025-02-12 23:57:01+00:00      0      75             0.0           0.0
# 2025-02-12 23:58:02+00:00      0      75             0.0           0.0
# 2025-02-12 23:59:01+00:00      0      75             0.0           0.0
# 2025-02-13 00:00:02+00:00      0      75             0.0           1.0
# 2025-02-13 00:02:02+00:00      0      75             0.0           1.0
#
#                            moving_average_21  is_important_event  hour  \
# measured_at
# 2025-02-12 23:57:01+00:00                3.0                   0    23
# 2025-02-12 23:58:02+00:00                3.0                   0    23
# 2025-02-12 23:59:01+00:00                3.0                   0    23
# 2025-02-13 00:00:02+00:00                4.0                   0     0
# 2025-02-13 00:02:02+00:00                4.0                   0     0
#
#                            day_of_week  month  is_weekend  is_holiday  lag_1h  \
# measured_at
# 2025-02-12 23:57:01+00:00            2      2           0           0     0.0
# 2025-02-12 23:58:02+00:00            2      2           0           0     0.0
# 2025-02-12 23:59:01+00:00            2      2           0           0     0.0
# 2025-02-13 00:00:02+00:00            3      2           0           0     0.0
# 2025-02-13 00:02:02+00:00            3      2           0           0     0.0
#
#                            lag_3h  lag_24h  lag_72h  lag_7d
# measured_at
# 2025-02-12 23:57:01+00:00     0.0      0.0      0.0    24.0
# 2025-02-12 23:58:02+00:00     0.0      0.0      0.0    24.0
# 2025-02-12 23:59:01+00:00     0.0      0.0      0.0    24.0
# 2025-02-13 00:00:02+00:00     0.0      0.0      0.0    24.0
# 2025-02-13 00:02:02+00:00            3      2           0           0
#
#                               lag_1h     lag_3h    lag_24h  lag_72h     lag_7d
# measured_at
# 2025-02-12 23:57:01+00:00  25.925926  27.777778  35.185185      0.0  92.592593
# 2025-02-12 23:58:02+00:00  25.925926  27.777778  35.185185      0.0  92.592593
# 2025-02-12 23:59:01+00:00  25.925926  27.777778  35.185185      0.0  92.592593
# 2025-02-13 00:00:02+00:00  25.925926  27.777778  35.185185      0.0  92.592593
# 2025-02-13 00:02:02+00:00  25.925926  27.777778  35.185185      0.0  92.592593

# %%
# Porządkuje trochę zbędne kolumny (np. dla Architektury, informacje o ludziach w SKS są zbędne)


df_model_architektura = df_model_architektura.drop(columns=['active_users', 'moving_average_21'])

df_model_architektura.head()
# Out:
#                            trend  places  occupancy_rate  is_important_event  \
# measured_at
# 2025-02-12 23:57:01+00:00      0      75             0.0                   0
# 2025-02-12 23:58:02+00:00      0      75             0.0                   0
# 2025-02-12 23:59:01+00:00      0      75             0.0                   0
# 2025-02-13 00:00:02+00:00      0      75             0.0                   0
# 2025-02-13 00:02:02+00:00      0      75             0.0                   0
#
#                            hour  day_of_week  month  is_weekend  is_holiday  \
# measured_at
# 2025-02-12 23:57:01+00:00    23            2      2           0           0
# 2025-02-12 23:58:02+00:00    23            2      2           0           0
# 2025-02-12 23:59:01+00:00    23            2      2           0           0
# 2025-02-13 00:00:02+00:00     0            3      2           0           0
# 2025-02-13 00:02:02+00:00     0            3      2           0           0
#
#                            lag_1h  lag_3h  lag_24h  lag_72h  lag_7d
# measured_at
# 2025-02-12 23:57:01+00:00     0.0     0.0      0.0      0.0    24.0
# 2025-02-12 23:58:02+00:00     0.0     0.0      0.0      0.0    24.0
# 2025-02-12 23:59:01+00:00     0.0     0.0      0.0      0.0    24.0
# 2025-02-13 00:00:02+00:00     0.0     0.0      0.0      0.0    24.0
# 2025-02-13 00:02:02+00:00     0.0     0.0      0.0      0.0    24.0

# %% [markdown]
# ## **Piękne wizualizacje:**

# %%
# Wybieramy tylko numeryczne kolumny, które mają sens do korelacji
cols_to_corr = ['occupancy_rate', 'active_users', 'is_important_event', 'hour', 'day_of_week', 'is_holiday', 'month', 'lag_1h', 'lag_3h', 'lag_24h', 'lag_72h', 'lag_7d']

# Obliczamy korelację
corr_matrix = df_model[cols_to_corr].corr()

# 3. Rysowanie
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True,fmt=".2f", cmap='coolwarm',vmin=-1, vmax=1,linewidths=1.5)

plt.title('Macierz korelacji dla wszystkich parkingów:')
plt.show()

# %%
# Get parking columns (these are the one-hot encoded parking names)
parking_cols = [c for c in df_model.columns if c in unique_parking_names]
df_model['temp_name'] = df_model[parking_cols].idxmax(axis=1)

monthly_heatmap = df_model.groupby(['temp_name', 'month'])['occupancy_rate'].mean().unstack()

# Rysowanie
plt.figure(figsize=(12, 6))
sns.heatmap(monthly_heatmap, cmap='magma_r', annot=True, fmt=".2f")

plt.title('Sezonowość: Średnia zajętość (%) w poszczególnych miesiącach')
plt.xlabel('Miesiąc')
plt.ylabel('Parking')
plt.show()
